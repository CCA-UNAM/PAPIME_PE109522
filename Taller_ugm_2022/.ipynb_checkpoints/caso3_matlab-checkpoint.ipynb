% %% [markdown]
% ![RAUGM_horizontal.png](attachment:RAUGM_horizontal.png)

% %%
help sin
% Out:
%  SIN    Sine of argument in radians.
%     SIN(X) is the sine of the elements of X.
%
%     See also ASIN, SIND, SINPI.
%
%     Documentation for sin
%        doc sin
%
%     Other uses of sin
%
%        codistributed/sin    gpuArray/sin
