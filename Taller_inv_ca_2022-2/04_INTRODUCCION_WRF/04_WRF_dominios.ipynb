# %% [markdown]
# ## Dominios
#
# * Definen el área de simulación. Un anidamiento es un dominio que está completamente contenido en un dominio padre.
# * Un dominio anidado tiene exactamente un padre.
# * Un dominio puede tener uno o más hijos.
#
# **Dos anidamientos en el mismo nivel con un dominio padre en común**
# <div align="left">
# <img src="attachment:22ae6829-b7a8-4fd7-824c-28a91bd8b982.png" width="350" height="250" />
# </div>
#
# <p></p>
#
# **Dos niveles de anidamiento con subdominio 1 como dominio padre de 2**
# <div align="left">
# <img src="attachment:5a9fb73d-d3b6-4f0f-b2fd-f3882cfd165b.png" width="350" height="250" />
# </div>
#
# <p>
# De los siguientes ejemplos ¿cuál es válido y cuál no?
# </p>
# <div align="left">
# <img src="attachment:11cafaca-c80d-4ce1-94a3-f00cb30ff2a4.png" width="350" height="250" />
# </div>
#
# <div align="left">
# <img src="attachment:a1a26eb0-83b5-48b5-ae96-90305a509112.png" width="350" height="250" />
# </div>
#
# Finalmente, la proporción de anidamiento es 3:1
#
# <div align="left">
# <img src="attachment:67b2e31b-1182-455c-bedf-1ae49433f9c5.png" width="350" height="250" />
# </div>
